# %% [markdown]
# <a href="https://colab.research.google.com/github/pgurazada/explore-dinov2/blob/main/painting_style_classification_dinov2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this exercise, we train a classification model that uses the feature extraction capabilities of [Dino V2](https://arxiv.org/pdf/2304.07193.pdf).

# %% [markdown]
# # Imports

# %%
# !pip install -q datasets flaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.0 MB/s eta 0:00:00

# %%
import os
import torch

import numpy as np
import pandas as pd

import torchvision.transforms as T

from PIL import Image

from tqdm import tqdm

from datasets import load_dataset

from flaml import AutoML

# %%
# !pip show torch torchvision
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: fastai, torchaudio, torchdata, torchtext, torchvision
# ---
# Name: torchvision
# Version: 0.16.0+cu118
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, requests, torch
# Required-by: fastai

# %% [markdown]
# # Data

# %%
painting_style_ds = load_dataset(
    "keremberke/painting-style-classification",
    name="full"
)
# Out:
# Downloading builder script:   0%|          | 0.00/4.82k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/150M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.8M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
train_data = {}

for file in painting_style_ds['train']:
    train_data[file['image_file_path']] = file['labels']

# %%
test_data = {}

for file in painting_style_ds['test']:
    test_data[file['image_file_path']] = file['labels']

# %% [markdown]
# # Model for Embeddings

# %%
dinov2_vit14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vitb14")
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitb14_pretrain.pth
# 100%|██████████| 330M/330M [00:03<00:00, 101MB/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
dinov2_vit14.to(device)
# Out:
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
transform_image = T.Compose(
    [
        T.ToTensor(),
        T.Resize(244, antialias=True),
        T.CenterCrop(224),
        T.Normalize([0.5], [0.5])
    ]
)

# %%
def load_image(img: str) -> torch.Tensor:
    """
    Load an image and return a tensor that can be used as an input to DINOv2.
    """
    img = Image.open(img)

    transformed_img = transform_image(img)[:3].unsqueeze(0)

    return transformed_img

# %%
def compute_embeddings(files: list) -> dict:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    all_embeddings = {}

    with torch.no_grad():
      for i, file in enumerate(tqdm(files)):
        embeddings = dinov2_vit14(load_image(file).to(device))

        all_embeddings[file] = np.array(embeddings[0].cpu().numpy()).reshape(1, -1).tolist()

    return all_embeddings

# %%
train_embeddings = compute_embeddings(train_data.keys())
# Out:
# 100%|██████████| 4493/4493 [02:02<00:00, 36.55it/s]

# %%
test_embeddings = compute_embeddings(test_data.keys())
# Out:
# 100%|██████████| 629/629 [00:15<00:00, 39.97it/s]

# %%
ytrain = np.array([train_data[file] for file in train_data.keys()])
train_embedding_list = list(train_embeddings.values())
Xtrain = np.array(train_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

ytest = np.array([test_data[file] for file in test_data.keys()])
test_embedding_list = list(test_embeddings.values())
Xtest = np.array(test_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

# %% [markdown]
# # Model for Classification

# %%
automl = AutoML()

# %%
automl.fit(
    X_train=Xtrain, y_train=ytrain,
    time_budget=240,
    log_file_name='painting_style.log',
    task='classification',
    metric='accuracy',
    split_ratio=.3
)
# Out:
# [flaml.automl.logger: 12-13 12:06:48] {1679} INFO - task = classification
# [flaml.automl.logger: 12-13 12:06:48] {1690} INFO - Evaluation method: holdout
# INFO:flaml.automl.task.generic_task:class 2 augmented from 5 to 20
# INFO:flaml.automl.task.generic_task:class 5 augmented from 6 to 24
# INFO:flaml.automl.task.generic_task:class 6 augmented from 13 to 26
# INFO:flaml.automl.task.generic_task:class 22 augmented from 14 to 28
# [flaml.automl.logger: 12-13 12:06:48] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 12-13 12:06:48] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 12-13 12:06:48] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-13 12:06:52] {2344} INFO - Estimated sufficient time budget=33567s. Estimated necessary time budget=774s.
# [flaml.automl.logger: 12-13 12:06:52] {2391} INFO -  at 3.5s,	estimator lgbm's best error=0.7300,	best estimator lgbm's best error=0.7300
# [flaml.automl.logger: 12-13 12:06:52] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-13 12:06:55] {2391} INFO -  at 7.1s,	estimator lgbm's best error=0.7300,	best estimator lgbm's best error=0.7300
# [flaml.automl.logger: 12-13 12:06:55] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 12-13 12:06:57] {2391} INFO -  at 8.6s,	estimator lgbm's best error=0.6643,	best estimator lgbm's best error=0.6643
# [flaml.automl.logger: 12-13 12:06:57] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:03] {2391} INFO -  at 14.8s,	estimator lgbm's best error=0.6643,	best estimator lgbm's best error=0.6643
# [flaml.automl.logger: 12-13 12:07:03] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 12-13 12:07:09] {2391} INFO -  at 20.6s,	estimator xgboost's best error=0.6758,	best estimator lgbm's best error=0.6643
# [flaml.automl.logger: 12-13 12:07:09] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:10] {2391} INFO -  at 21.8s,	estimator lgbm's best error=0.6643,	best estimator lgbm's best error=0.6643
# [flaml.automl.logger: 12-13 12:07:10] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:12] {2391} INFO -  at 23.5s,	estimator lgbm's best error=0.6643,	best estimator lgbm's best error=0.6643
# [flaml.automl.logger: 12-13 12:07:12] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:14] {2391} INFO -  at 25.6s,	estimator lgbm's best error=0.6643,	best estimator lgbm's best error=0.6643
# [flaml.automl.logger: 12-13 12:07:14] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:15] {2391} INFO -  at 27.3s,	estimator lgbm's best error=0.6513,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:15] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-13 12:07:21] {2391} INFO -  at 32.7s,	estimator xgboost's best error=0.6758,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:21] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 12-13 12:07:24] {2391} INFO -  at 36.2s,	estimator xgboost's best error=0.6758,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:24] {2218} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:24] {2391} INFO -  at 36.3s,	estimator extra_tree's best error=0.8253,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:24] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:24] {2391} INFO -  at 36.4s,	estimator extra_tree's best error=0.7877,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:24] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:24] {2391} INFO -  at 36.4s,	estimator extra_tree's best error=0.7877,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:24] {2218} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:25] {2391} INFO -  at 36.5s,	estimator extra_tree's best error=0.7877,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:25] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 12-13 12:07:28] {2391} INFO -  at 39.5s,	estimator xgboost's best error=0.6758,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:28] {2218} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:28] {2391} INFO -  at 39.6s,	estimator extra_tree's best error=0.7675,	best estimator lgbm's best error=0.6513
# [flaml.automl.logger: 12-13 12:07:28] {2218} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:35] {2391} INFO -  at 46.9s,	estimator lgbm's best error=0.6238,	best estimator lgbm's best error=0.6238
# [flaml.automl.logger: 12-13 12:07:35] {2218} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:35] {2391} INFO -  at 47.0s,	estimator extra_tree's best error=0.7675,	best estimator lgbm's best error=0.6238
# [flaml.automl.logger: 12-13 12:07:35] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 12-13 12:07:41] {2391} INFO -  at 53.0s,	estimator xgboost's best error=0.6758,	best estimator lgbm's best error=0.6238
# [flaml.automl.logger: 12-13 12:07:41] {2218} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 12-13 12:07:41] {2391} INFO -  at 53.1s,	estimator extra_tree's best error=0.7502,	best estimator lgbm's best error=0.6238
# [flaml.automl.logger: 12-13 12:07:41] {2218} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 12-13 12:07:43] {2391} INFO -  at 54.7s,	estimator lgbm's best error=0.6238,	best estimator lgbm's best error=0.6238
# [flaml.automl.logger: 12-13 12:07:43] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 12-13 12:08:03] {2391} INFO -  at 75.3s,	estimator lgbm's best error=0.5899,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:03] {2218} INFO - iteration 23, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:03] {2391} INFO -  at 75.4s,	estimator extra_tree's best error=0.7300,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:03] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:04] {2391} INFO -  at 75.5s,	estimator extra_tree's best error=0.7300,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:04] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:04] {2391} INFO -  at 75.6s,	estimator extra_tree's best error=0.7300,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:04] {2218} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:04] {2391} INFO -  at 75.8s,	estimator extra_tree's best error=0.7069,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:04] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:04] {2391} INFO -  at 75.9s,	estimator extra_tree's best error=0.7069,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:04] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:04] {2391} INFO -  at 76.2s,	estimator extra_tree's best error=0.6953,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:04] {2218} INFO - iteration 29, current learner rf
# [flaml.automl.logger: 12-13 12:08:05] {2391} INFO -  at 76.8s,	estimator rf's best error=0.8166,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:05] {2218} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 12-13 12:08:05] {2391} INFO -  at 77.0s,	estimator rf's best error=0.7690,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:05] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 12-13 12:08:38] {2391} INFO -  at 109.6s,	estimator lgbm's best error=0.5899,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:38] {2218} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 12-13 12:08:38] {2391} INFO -  at 109.8s,	estimator rf's best error=0.7690,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:38] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:38] {2391} INFO -  at 110.1s,	estimator extra_tree's best error=0.6953,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:38] {2218} INFO - iteration 34, current learner rf
# [flaml.automl.logger: 12-13 12:08:41] {2391} INFO -  at 113.1s,	estimator rf's best error=0.7690,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:41] {2218} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 12-13 12:08:45] {2391} INFO -  at 116.8s,	estimator xgboost's best error=0.6715,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:45] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:45] {2391} INFO -  at 117.2s,	estimator extra_tree's best error=0.6903,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:45] {2218} INFO - iteration 37, current learner rf
# [flaml.automl.logger: 12-13 12:08:46] {2391} INFO -  at 117.6s,	estimator rf's best error=0.7487,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:46] {2218} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:46] {2391} INFO -  at 118.0s,	estimator extra_tree's best error=0.6383,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:46] {2218} INFO - iteration 39, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:47] {2391} INFO -  at 118.5s,	estimator extra_tree's best error=0.6383,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:47] {2218} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:47] {2391} INFO -  at 118.8s,	estimator extra_tree's best error=0.6383,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:47] {2218} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 12-13 12:08:48] {2391} INFO -  at 120.2s,	estimator extra_tree's best error=0.6383,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:08:48] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 12-13 12:09:01] {2391} INFO -  at 133.2s,	estimator lgbm's best error=0.5899,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:09:01] {2218} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:02] {2391} INFO -  at 134.0s,	estimator extra_tree's best error=0.6282,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:09:02] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:03] {2391} INFO -  at 134.7s,	estimator extra_tree's best error=0.6282,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:09:03] {2218} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:04] {2391} INFO -  at 135.6s,	estimator extra_tree's best error=0.6130,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:09:04] {2218} INFO - iteration 46, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:05] {2391} INFO -  at 136.7s,	estimator extra_tree's best error=0.6130,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:09:05] {2218} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:07] {2391} INFO -  at 138.8s,	estimator extra_tree's best error=0.6130,	best estimator lgbm's best error=0.5899
# [flaml.automl.logger: 12-13 12:09:07] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 12-13 12:09:28] {2391} INFO -  at 160.3s,	estimator lgbm's best error=0.5769,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 12-13 12:09:28] {2218} INFO - iteration 49, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:29] {2391} INFO -  at 161.0s,	estimator extra_tree's best error=0.6130,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 12-13 12:09:29] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 12-13 12:09:30] {2391} INFO -  at 161.8s,	estimator extra_tree's best error=0.6130,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 12-13 12:09:30] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 12-13 12:09:30] {2391} INFO -  at 162.5s,	estimator rf's best error=0.7487,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 12-13 12:09:30] {2218} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 12-13 12:09:32] {2391} INFO -  at 164.0s,	estimator rf's best error=0.7487,	best estimator lgbm's best error=0.5769
# [flaml.automl.logger: 12-13 12:09:32] {2218} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 12-13 12:09:53] {2391} INFO -  at 184.8s,	estimator lgbm's best error=0.5610,	best estimator lgbm's best error=0.5610
# [flaml.automl.logger: 12-13 12:09:53] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 12-13 12:10:17] {2391} INFO -  at 209.1s,	estimator lgbm's best error=0.5610,	best estimator lgbm's best error=0.5610
# [flaml.automl.logger: 12-13 12:10:17] {2218} INFO - iteration 55, current learner xgboost
# [flaml.automl.logger: 12-13 12:10:25] {2391} INFO -  at 216.7s,	estimator xgboost's best error=0.6404,	best estimator lgbm's best error=0.5610
# [flaml.automl.logger: 12-13 12:10:25] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 12-13 12:10:35] {2391} INFO -  at 227.3s,	estimator lgbm's best error=0.5610,	best estimator lgbm's best error=0.5610
# [flaml.automl.logger: 12-13 12:10:35] {2218} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 12-13 12:10:48] {2391} INFO -  at 239.5s,	estimator xgboost's best error=0.6224,	best estimator lgbm's best error=0.5610
# [flaml.automl.logger: 12-13 12:10:48] {2218} INFO - iteration 58, current learner rf
# [flaml.automl.logger: 12-13 12:10:49] {2391} INFO -  at 240.7s,	estimator rf's best error=0.7487,	best estimator lgbm's best error=0.5610
# [flaml.automl.logger: 12-13 12:11:13] {2627} INFO - retrain lgbm for 23.8s
# [flaml.automl.logger: 12-13 12:11:13] {2630} INFO - retrained model: LGBMClassifier(colsample_bytree=0.8345075630938922,
#                learning_rate=0.1111072858208537, max_bin=127,
#                min_child_samples=9, n_estimators=1, n_jobs=-1, num_leaves=13,
#                reg_alpha=0.006958608037974516, reg_lambda=1.0522050334575102,
#                verbose=-1)
# [flaml.automl.logger: 12-13 12:11:13] {1930} INFO - fit succeeded
# [flaml.automl.logger: 12-13 12:11:13] {1931} INFO - Time taken to find the best model: 184.82693934440613

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print(f'Best accuracy on validation data: {(1-automl.best_loss):.3f}')
print(f'Training duration of best run: {(automl.best_config_train_time):.4f} s')
# Out:
# Best ML leaner: lgbm
# Best hyperparmeter config: {'n_estimators': 28, 'num_leaves': 13, 'min_child_samples': 9, 'learning_rate': 0.1111072858208537, 'log_max_bin': 7, 'colsample_bytree': 0.8345075630938922, 'reg_alpha': 0.006958608037974516, 'reg_lambda': 1.0522050334575102}
# Best accuracy on validation data: 0.439
# Training duration of best run: 23.8047 s

# %%
automl.model.estimator
# Out:
# LGBMClassifier(colsample_bytree=0.8345075630938922,
#                learning_rate=0.1111072858208537, max_bin=127,
#                min_child_samples=9, n_estimators=1, n_jobs=-1, num_leaves=13,
#                reg_alpha=0.006958608037974516, reg_lambda=1.0522050334575102,
#                verbose=-1)

# %%
ypred = automl.predict(Xtest)

# %%
(ypred == ytest).mean()
# Out:
# 0.4117647058823529
