# %% [markdown]
# <a href="https://colab.research.google.com/github/pgurazada/explore-dinov2/blob/main/skin_cancer_classification_dinov2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this exercise, we train a classification model that uses the feature extraction capabilities of [Dino V2](https://arxiv.org/pdf/2304.07193.pdf).

# %% [markdown]
# # Imports

# %%
# !pip install -q datasets flaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.0 MB/s eta 0:00:00

# %%
import os
import torch

import numpy as np
import torchvision.transforms as T

from PIL import Image
from tqdm import tqdm
from datasets import load_dataset
from flaml import AutoML

# %%
# !pip show torch torchvision
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: fastai, torchaudio, torchdata, torchtext, torchvision
# ---
# Name: torchvision
# Version: 0.16.0+cu118
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, requests, torch
# Required-by: fastai

# %% [markdown]
# # Data

# %%
skin_cancer_ds = load_dataset("marmal88/skin_cancer")
# Out:
# Downloading readme:   0%|          | 0.00/3.24k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/521M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/525M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/527M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/528M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/341M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/348M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/355M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/9577 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2492 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1285 [00:00<?, ? examples/s]

# %% [markdown]
# # Model for Embeddings

# %%
dinov2_vit14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vitb14")
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitb14_pretrain.pth
# 100%|██████████| 330M/330M [00:01<00:00, 217MB/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
dinov2_vit14.to(device)
# Out:
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
transform_image = T.Compose(
    [
        T.ToTensor(),
        T.Resize(244, antialias=True),
        T.CenterCrop(224),
        T.Normalize([0.5], [0.5])
    ]
)

# %%
def load_image(img: str) -> torch.Tensor:
    """
    Load an image and return a tensor that can be used as an input to DINOv2.
    """

    transformed_img = transform_image(img)[:3].unsqueeze(0)

    return transformed_img

# %%
def compute_embeddings(files) -> dict:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    all_embeddings = {}
    bad_image_indices = []

    with torch.no_grad():
      for i, file in enumerate(tqdm(files)):
        try:
            embeddings = dinov2_vit14(load_image(file['image']).to(device))
            all_embeddings[i] = np.array(embeddings[0].cpu().numpy()).reshape(1, -1).tolist()
        except Exception as e:
            bad_image_indices.append(i)
            continue

    return all_embeddings, bad_image_indices

# %%
train_embeddings, bad_train_image_indices = compute_embeddings(skin_cancer_ds['train'])
# Out:
# 100%|██████████| 9577/9577 [05:04<00:00, 31.48it/s]

# %%
len(train_embeddings)
# Out:
# 9577

# %%
len(bad_train_image_indices)
# Out:
# []

# %%
test_embeddings, bad_test_image_indices = compute_embeddings(skin_cancer_ds['test'])
# Out:
# 100%|██████████| 1285/1285 [00:38<00:00, 33.48it/s]

# %%
len(test_embeddings)
# Out:
# 1285

# %%
len(bad_test_image_indices)
# Out:
# 0

# %%
ytrain = np.array([file['dx'] for file in skin_cancer_ds['train']])
train_embedding_list = list(train_embeddings.values())
Xtrain = np.array(train_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

# %%
ytest = np.array([file['dx'] for file in skin_cancer_ds['test']])
test_embedding_list = list(test_embeddings.values())
Xtest = np.array(test_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

# %% [markdown]
# # Model for Classification

# %%
automl = AutoML()

# %%
automl.fit(
    X_train=Xtrain, y_train=ytrain,
    time_budget=240,
    log_file_name='skin-cancer.log',
    task='classification',
    metric='accuracy',
    split_ratio=.3
)
# Out:
# [flaml.automl.logger: 12-13 15:30:42] {1679} INFO - task = classification
# [flaml.automl.logger: 12-13 15:30:42] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-13 15:30:42] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 12-13 15:30:42] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 12-13 15:30:42] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-13 15:30:44] {2344} INFO - Estimated sufficient time budget=18421s. Estimated necessary time budget=425s.
# [flaml.automl.logger: 12-13 15:30:44] {2391} INFO -  at 2.1s,	estimator lgbm's best error=0.3322,	best estimator lgbm's best error=0.3322
# [flaml.automl.logger: 12-13 15:30:44] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-13 15:30:46] {2391} INFO -  at 4.0s,	estimator lgbm's best error=0.3322,	best estimator lgbm's best error=0.3322
# [flaml.automl.logger: 12-13 15:30:46] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 12-13 15:30:47] {2391} INFO -  at 5.5s,	estimator lgbm's best error=0.3047,	best estimator lgbm's best error=0.3047
# [flaml.automl.logger: 12-13 15:30:47] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 12-13 15:30:49] {2391} INFO -  at 7.4s,	estimator xgboost's best error=0.3113,	best estimator lgbm's best error=0.3047
# [flaml.automl.logger: 12-13 15:30:49] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 12-13 15:30:54] {2391} INFO -  at 12.7s,	estimator lgbm's best error=0.2853,	best estimator lgbm's best error=0.2853
# [flaml.automl.logger: 12-13 15:30:54] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 12-13 15:30:56] {2391} INFO -  at 14.4s,	estimator xgboost's best error=0.3113,	best estimator lgbm's best error=0.2853
# [flaml.automl.logger: 12-13 15:30:56] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 12-13 15:30:58] {2391} INFO -  at 15.9s,	estimator lgbm's best error=0.2853,	best estimator lgbm's best error=0.2853
# [flaml.automl.logger: 12-13 15:30:58] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 12-13 15:31:00] {2391} INFO -  at 18.5s,	estimator lgbm's best error=0.2853,	best estimator lgbm's best error=0.2853
# [flaml.automl.logger: 12-13 15:31:00] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 12-13 15:31:07] {2391} INFO -  at 25.5s,	estimator lgbm's best error=0.2679,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:07] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-13 15:31:09] {2391} INFO -  at 27.3s,	estimator xgboost's best error=0.3026,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:09] {2218} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 12-13 15:31:09] {2391} INFO -  at 27.4s,	estimator extra_tree's best error=0.3322,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:09] {2218} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 12-13 15:31:09] {2391} INFO -  at 27.5s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:09] {2218} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 12-13 15:31:10] {2391} INFO -  at 28.0s,	estimator rf's best error=0.3322,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:10] {2218} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 12-13 15:31:10] {2391} INFO -  at 28.3s,	estimator rf's best error=0.3231,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:10] {2218} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 12-13 15:31:10] {2391} INFO -  at 28.5s,	estimator rf's best error=0.3231,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:10] {2218} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 12-13 15:31:10] {2391} INFO -  at 28.6s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:10] {2218} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 12-13 15:31:13] {2391} INFO -  at 31.0s,	estimator lgbm's best error=0.2679,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:13] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 12-13 15:31:13] {2391} INFO -  at 31.2s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2679
# [flaml.automl.logger: 12-13 15:31:13] {2218} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 12-13 15:31:26] {2391} INFO -  at 44.6s,	estimator lgbm's best error=0.2370,	best estimator lgbm's best error=0.2370
# [flaml.automl.logger: 12-13 15:31:26] {2218} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 12-13 15:31:28] {2391} INFO -  at 45.9s,	estimator rf's best error=0.3231,	best estimator lgbm's best error=0.2370
# [flaml.automl.logger: 12-13 15:31:28] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 12-13 15:31:28] {2391} INFO -  at 46.4s,	estimator rf's best error=0.3179,	best estimator lgbm's best error=0.2370
# [flaml.automl.logger: 12-13 15:31:28] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 12-13 15:31:30] {2391} INFO -  at 48.5s,	estimator xgboost's best error=0.2940,	best estimator lgbm's best error=0.2370
# [flaml.automl.logger: 12-13 15:31:30] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 12-13 15:31:37] {2391} INFO -  at 55.0s,	estimator lgbm's best error=0.2370,	best estimator lgbm's best error=0.2370
# [flaml.automl.logger: 12-13 15:31:37] {2218} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 12-13 15:33:39] {2391} INFO -  at 177.5s,	estimator lgbm's best error=0.2137,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:39] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:39] {2391} INFO -  at 177.6s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:39] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:39] {2391} INFO -  at 177.8s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:39] {2218} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 12-13 15:33:42] {2391} INFO -  at 180.4s,	estimator xgboost's best error=0.2894,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:42] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:42] {2391} INFO -  at 180.5s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:42] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:42] {2391} INFO -  at 180.7s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:42] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:43] {2391} INFO -  at 180.8s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:43] {2218} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 12-13 15:33:44] {2391} INFO -  at 182.0s,	estimator rf's best error=0.3179,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:44] {2218} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 12-13 15:33:46] {2391} INFO -  at 184.2s,	estimator rf's best error=0.3158,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:46] {2218} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 12-13 15:33:49] {2391} INFO -  at 187.1s,	estimator xgboost's best error=0.2894,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:49] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:49] {2391} INFO -  at 187.3s,	estimator extra_tree's best error=0.3290,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:49] {2218} INFO - iteration 34, current learner rf
# [flaml.automl.logger: 12-13 15:33:50] {2391} INFO -  at 188.8s,	estimator rf's best error=0.3082,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:50] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 12-13 15:33:51] {2391} INFO -  at 189.3s,	estimator rf's best error=0.3082,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:51] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 12-13 15:33:51] {2391} INFO -  at 189.5s,	estimator extra_tree's best error=0.3228,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:51] {2218} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 12-13 15:33:57] {2391} INFO -  at 194.9s,	estimator xgboost's best error=0.2571,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:33:57] {2218} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 12-13 15:34:04] {2391} INFO -  at 202.7s,	estimator xgboost's best error=0.2540,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:04] {2218} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 12-13 15:34:06] {2391} INFO -  at 204.0s,	estimator rf's best error=0.3082,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:06] {2218} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:06] {2391} INFO -  at 204.1s,	estimator extra_tree's best error=0.3228,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:06] {2218} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:06] {2391} INFO -  at 204.4s,	estimator extra_tree's best error=0.3228,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:06] {2218} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 12-13 15:34:09] {2391} INFO -  at 207.7s,	estimator rf's best error=0.2971,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:09] {2218} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:10] {2391} INFO -  at 207.9s,	estimator extra_tree's best error=0.3214,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:10] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:10] {2391} INFO -  at 208.1s,	estimator extra_tree's best error=0.3214,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:10] {2218} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:10] {2391} INFO -  at 208.3s,	estimator extra_tree's best error=0.3162,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:10] {2218} INFO - iteration 46, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:10] {2391} INFO -  at 208.5s,	estimator extra_tree's best error=0.3145,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:10] {2218} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:10] {2391} INFO -  at 208.7s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:10] {2218} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 12-13 15:34:18] {2391} INFO -  at 216.1s,	estimator xgboost's best error=0.2540,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:18] {2218} INFO - iteration 49, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:18] {2391} INFO -  at 216.5s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:18] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:18] {2391} INFO -  at 216.7s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:18] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 12-13 15:34:19] {2391} INFO -  at 217.5s,	estimator rf's best error=0.2971,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:19] {2218} INFO - iteration 52, current learner xgboost
# [flaml.automl.logger: 12-13 15:34:32] {2391} INFO -  at 230.6s,	estimator xgboost's best error=0.2397,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:32] {2218} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 12-13 15:34:39] {2391} INFO -  at 237.7s,	estimator rf's best error=0.2926,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:39] {2218} INFO - iteration 54, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:40] {2391} INFO -  at 237.9s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:40] {2218} INFO - iteration 55, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:40] {2391} INFO -  at 238.1s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:40] {2218} INFO - iteration 56, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:40] {2391} INFO -  at 238.3s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:40] {2218} INFO - iteration 57, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:40] {2391} INFO -  at 238.7s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:40] {2218} INFO - iteration 58, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:41] {2391} INFO -  at 238.9s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:41] {2218} INFO - iteration 59, current learner extra_tree
# [flaml.automl.logger: 12-13 15:34:41] {2391} INFO -  at 239.2s,	estimator extra_tree's best error=0.3110,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:34:41] {2218} INFO - iteration 60, current learner xgb_limitdepth
# [flaml.automl.logger: 12-13 15:34:43] {2391} INFO -  at 241.6s,	estimator xgb_limitdepth's best error=0.3006,	best estimator lgbm's best error=0.2137
# [flaml.automl.logger: 12-13 15:36:55] {2627} INFO - retrain lgbm for 132.1s
# [flaml.automl.logger: 12-13 15:36:55] {2630} INFO - retrained model: LGBMClassifier(colsample_bytree=0.8345075630938922,
#                learning_rate=0.15922418945050276, max_bin=1023,
#                min_child_samples=9, n_estimators=1, n_jobs=-1, num_leaves=15,
#                reg_alpha=0.0009765625, reg_lambda=1.6702305601383631,
#                verbose=-1)
# [flaml.automl.logger: 12-13 15:36:55] {1930} INFO - fit succeeded
# [flaml.automl.logger: 12-13 15:36:55] {1931} INFO - Time taken to find the best model: 177.47046852111816

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print(f'Best accuracy on validation data: {(1-automl.best_loss):.3f}')
print(f'Training duration of best run: {(automl.best_config_train_time):.4f} s')
# Out:
# Best ML leaner: lgbm
# Best hyperparmeter config: {'n_estimators': 77, 'num_leaves': 15, 'min_child_samples': 9, 'learning_rate': 0.15922418945050276, 'log_max_bin': 10, 'colsample_bytree': 0.8345075630938922, 'reg_alpha': 0.0009765625, 'reg_lambda': 1.6702305601383631}
# Best accuracy on validation data: 0.786
# Training duration of best run: 132.0551 s

# %%
automl.model.estimator
# Out:
# LGBMClassifier(colsample_bytree=0.8345075630938922,
#                learning_rate=0.15922418945050276, max_bin=1023,
#                min_child_samples=9, n_estimators=1, n_jobs=-1, num_leaves=15,
#                reg_alpha=0.0009765625, reg_lambda=1.6702305601383631,
#                verbose=-1)

# %%
ypred = automl.predict(Xtest)

# %%
(ypred == ytest).mean()
# Out:
# 0.9603112840466926
