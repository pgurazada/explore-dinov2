# %% [markdown]
# <a href="https://colab.research.google.com/github/pgurazada/explore-dinov2/blob/main/bean_leaf_classification_dinov2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this exercise, we train a classification model that uses the feature extraction capabilities of [Dino V2](https://arxiv.org/pdf/2304.07193.pdf).

# %% [markdown]
# # Imports

# %%
# !pip install -q datasets flaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 24.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.5 MB/s eta 0:00:00

# %%
import os
import torch

import numpy as np
import torchvision.transforms as T

from PIL import Image
from tqdm import tqdm
from datasets import load_dataset
from flaml import AutoML

# %%
# !pip show torch torchvision
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: fastai, torchaudio, torchdata, torchtext, torchvision
# ---
# Name: torchvision
# Version: 0.16.0+cu118
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, requests, torch
# Required-by: fastai

# %% [markdown]
# # Data

# %%
beans_ds = load_dataset("beans")
# Out:
# Downloading builder script:   0%|          | 0.00/3.61k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.24k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/4.75k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/144M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/18.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/17.7M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/1034 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/133 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/128 [00:00<?, ? examples/s]

# %%
train_data = {}

for file in beans_ds['train']:
    train_data[file['image_file_path']] = file['labels']

# %%
test_data = {}

for file in beans_ds['test']:
    test_data[file['image_file_path']] = file['labels']

# %% [markdown]
# # Model for Embeddings

# %%
dinov2_vit14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vitb14")
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitb14_pretrain.pth
# 100%|██████████| 330M/330M [00:02<00:00, 140MB/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
dinov2_vit14.to(device)
# Out:
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
transform_image = T.Compose(
    [
        T.ToTensor(),
        T.Resize(244, antialias=True),
        T.CenterCrop(224),
        T.Normalize([0.5], [0.5])
    ]
)

# %%
def load_image(img: str) -> torch.Tensor:
    """
    Load an image and return a tensor that can be used as an input to DINOv2.
    """
    img = Image.open(img)

    transformed_img = transform_image(img)[:3].unsqueeze(0)

    return transformed_img

# %%
def compute_embeddings(files: list) -> dict:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    all_embeddings = {}

    with torch.no_grad():
      for i, file in enumerate(tqdm(files)):
        embeddings = dinov2_vit14(load_image(file).to(device))

        all_embeddings[file] = np.array(embeddings[0].cpu().numpy()).reshape(1, -1).tolist()

    return all_embeddings

# %%
train_embeddings = compute_embeddings(train_data.keys())
# Out:
# 100%|██████████| 1034/1034 [00:35<00:00, 29.07it/s]

# %%
test_embeddings = compute_embeddings(test_data.keys())
# Out:
# 100%|██████████| 128/128 [00:03<00:00, 36.69it/s]

# %%
ytrain = np.array([train_data[file] for file in train_data.keys()])
train_embedding_list = list(train_embeddings.values())
Xtrain = np.array(train_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

ytest = np.array([test_data[file] for file in test_data.keys()])
test_embedding_list = list(test_embeddings.values())
Xtest = np.array(test_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

# %% [markdown]
# # Model for Classification

# %%
automl = AutoML()

# %%
automl.fit(
    X_train=Xtrain, y_train=ytrain,
    time_budget=240,
    log_file_name='beans.log',
    task='classification',
    metric='accuracy',
    split_ratio=.3
)
# Out:
# [flaml.automl.logger: 12-13 12:16:50] {1679} INFO - task = classification
# [flaml.automl.logger: 12-13 12:16:50] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-13 12:16:50] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 12-13 12:16:50] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 12-13 12:16:50] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-13 12:16:51] {2344} INFO - Estimated sufficient time budget=10211s. Estimated necessary time budget=235s.
# [flaml.automl.logger: 12-13 12:16:51] {2391} INFO -  at 1.1s,	estimator lgbm's best error=0.1342,	best estimator lgbm's best error=0.1342
# [flaml.automl.logger: 12-13 12:16:51] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-13 12:16:52] {2391} INFO -  at 2.2s,	estimator lgbm's best error=0.1342,	best estimator lgbm's best error=0.1342
# [flaml.automl.logger: 12-13 12:16:52] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 12-13 12:16:54] {2391} INFO -  at 3.9s,	estimator lgbm's best error=0.1342,	best estimator lgbm's best error=0.1342
# [flaml.automl.logger: 12-13 12:16:54] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 12-13 12:16:57] {2391} INFO -  at 6.7s,	estimator xgboost's best error=0.1725,	best estimator lgbm's best error=0.1342
# [flaml.automl.logger: 12-13 12:16:57] {2218} INFO - iteration 4, current learner extra_tree
# [flaml.automl.logger: 12-13 12:16:57] {2391} INFO -  at 6.8s,	estimator extra_tree's best error=0.3067,	best estimator lgbm's best error=0.1342
# [flaml.automl.logger: 12-13 12:16:57] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 12-13 12:16:58] {2391} INFO -  at 8.1s,	estimator lgbm's best error=0.1150,	best estimator lgbm's best error=0.1150
# [flaml.automl.logger: 12-13 12:16:58] {2218} INFO - iteration 6, current learner extra_tree
# [flaml.automl.logger: 12-13 12:16:59] {2391} INFO -  at 8.3s,	estimator extra_tree's best error=0.2620,	best estimator lgbm's best error=0.1150
# [flaml.automl.logger: 12-13 12:16:59] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:00] {2391} INFO -  at 9.7s,	estimator xgboost's best error=0.1725,	best estimator lgbm's best error=0.1150
# [flaml.automl.logger: 12-13 12:17:00] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:03] {2391} INFO -  at 12.4s,	estimator lgbm's best error=0.1118,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:03] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:03] {2391} INFO -  at 13.2s,	estimator xgboost's best error=0.1470,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:03] {2218} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:04] {2391} INFO -  at 13.3s,	estimator extra_tree's best error=0.2620,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:04] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:05] {2391} INFO -  at 14.6s,	estimator xgboost's best error=0.1470,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:05] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:05] {2391} INFO -  at 14.8s,	estimator extra_tree's best error=0.2204,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:05] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:05] {2391} INFO -  at 14.8s,	estimator extra_tree's best error=0.2204,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:05] {2218} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:05] {2391} INFO -  at 15.0s,	estimator extra_tree's best error=0.2141,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:05] {2218} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 12-13 12:17:05] {2391} INFO -  at 15.1s,	estimator rf's best error=0.2556,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:05] {2218} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 12-13 12:17:06] {2391} INFO -  at 15.2s,	estimator rf's best error=0.2173,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:06] {2218} INFO - iteration 17, current learner rf
# [flaml.automl.logger: 12-13 12:17:06] {2391} INFO -  at 15.3s,	estimator rf's best error=0.2173,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:06] {2218} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:07] {2391} INFO -  at 16.8s,	estimator lgbm's best error=0.1118,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:07] {2218} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 12-13 12:17:08] {2391} INFO -  at 17.3s,	estimator rf's best error=0.1821,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:08] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 12-13 12:17:08] {2391} INFO -  at 17.7s,	estimator rf's best error=0.1789,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:08] {2218} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 12-13 12:17:08] {2391} INFO -  at 18.1s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:08] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:09] {2391} INFO -  at 19.0s,	estimator lgbm's best error=0.1118,	best estimator lgbm's best error=0.1118
# [flaml.automl.logger: 12-13 12:17:09] {2218} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:12] {2391} INFO -  at 21.2s,	estimator lgbm's best error=0.1086,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:12] {2218} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 12-13 12:17:12] {2391} INFO -  at 21.4s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:12] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:12] {2391} INFO -  at 21.5s,	estimator extra_tree's best error=0.2141,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:12] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 12-13 12:17:12] {2391} INFO -  at 21.9s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:12] {2218} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 12-13 12:17:12] {2391} INFO -  at 22.2s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:12] {2218} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:14] {2391} INFO -  at 23.7s,	estimator xgboost's best error=0.1470,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:14] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:14] {2391} INFO -  at 24.0s,	estimator extra_tree's best error=0.1374,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:14] {2218} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 12-13 12:17:15] {2391} INFO -  at 24.4s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:15] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:16] {2391} INFO -  at 25.4s,	estimator lgbm's best error=0.1086,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:16] {2218} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:16] {2391} INFO -  at 25.9s,	estimator xgboost's best error=0.1470,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:16] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:16] {2391} INFO -  at 26.0s,	estimator extra_tree's best error=0.1374,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:16] {2218} INFO - iteration 34, current learner rf
# [flaml.automl.logger: 12-13 12:17:16] {2391} INFO -  at 26.2s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:16] {2218} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 26.3s,	estimator extra_tree's best error=0.1374,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 26.4s,	estimator extra_tree's best error=0.1310,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 26.5s,	estimator extra_tree's best error=0.1310,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 26.6s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 39, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 26.7s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 27.0s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:17] {2391} INFO -  at 27.2s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.1086
# [flaml.automl.logger: 12-13 12:17:17] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:20] {2391} INFO -  at 29.4s,	estimator lgbm's best error=0.0895,	best estimator lgbm's best error=0.0895
# [flaml.automl.logger: 12-13 12:17:20] {2218} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:20] {2391} INFO -  at 29.6s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0895
# [flaml.automl.logger: 12-13 12:17:20] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:20] {2391} INFO -  at 29.7s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0895
# [flaml.automl.logger: 12-13 12:17:20] {2218} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:20] {2391} INFO -  at 29.9s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0895
# [flaml.automl.logger: 12-13 12:17:20] {2218} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:23] {2391} INFO -  at 32.7s,	estimator lgbm's best error=0.0767,	best estimator lgbm's best error=0.0767
# [flaml.automl.logger: 12-13 12:17:23] {2218} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:23] {2391} INFO -  at 32.8s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0767
# [flaml.automl.logger: 12-13 12:17:23] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:25] {2391} INFO -  at 35.1s,	estimator lgbm's best error=0.0767,	best estimator lgbm's best error=0.0767
# [flaml.automl.logger: 12-13 12:17:25] {2218} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:30] {2391} INFO -  at 39.5s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:30] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:30] {2391} INFO -  at 39.6s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:30] {2218} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:33] {2391} INFO -  at 42.2s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:33] {2218} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:34] {2391} INFO -  at 43.7s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:34] {2218} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:35] {2391} INFO -  at 45.1s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:35] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:38] {2391} INFO -  at 47.8s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:38] {2218} INFO - iteration 55, current learner extra_tree
# [flaml.automl.logger: 12-13 12:17:38] {2391} INFO -  at 47.9s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:38] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:42] {2391} INFO -  at 51.8s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:42] {2218} INFO - iteration 57, current learner rf
# [flaml.automl.logger: 12-13 12:17:42] {2391} INFO -  at 52.0s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:42] {2218} INFO - iteration 58, current learner rf
# [flaml.automl.logger: 12-13 12:17:43] {2391} INFO -  at 52.3s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:43] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:44] {2391} INFO -  at 53.5s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:44] {2218} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:44] {2391} INFO -  at 54.1s,	estimator xgboost's best error=0.1246,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:44] {2218} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:48] {2391} INFO -  at 57.9s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:48] {2218} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:49] {2391} INFO -  at 58.5s,	estimator xgboost's best error=0.1054,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:49] {2218} INFO - iteration 63, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:50] {2391} INFO -  at 59.3s,	estimator xgboost's best error=0.1054,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:50] {2218} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 12-13 12:17:51] {2391} INFO -  at 61.0s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:51] {2218} INFO - iteration 65, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:52] {2391} INFO -  at 62.0s,	estimator xgboost's best error=0.0927,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:52] {2218} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 12-13 12:17:55] {2391} INFO -  at 64.7s,	estimator xgboost's best error=0.0927,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17:55] {2218} INFO - iteration 67, current learner rf
# [flaml.automl.logger: 12-13 12:17:55] {2391} INFO -  at 64.9s,	estimator rf's best error=0.1438,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:17
7s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:04] {2218} INFO - iteration 199, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:04] {2391} INFO -  at 193.9s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:04] {2218} INFO - iteration 200, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:06] {2391} INFO -  at 195.5s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:06] {2218} INFO - iteration 201, current learner rf
# [flaml.automl.logger: 12-13 12:20:06] {2391} INFO -  at 195.7s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:06] {2218} INFO - iteration 202, current learner xgboost
# [flaml.automl.logger: 12-13 12:20:10] {2391} INFO -  at 199.5s,	estimator xgboost's best error=0.0735,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:10] {2218} INFO - iteration 203, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:10] {2391} INFO -  at 199.7s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:10] {2218} INFO - iteration 204, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:10] {2391} INFO -  at 199.8s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:10] {2218} INFO - iteration 205, current learner rf
# [flaml.automl.logger: 12-13 12:20:10] {2391} INFO -  at 200.1s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:10] {2218} INFO - iteration 206, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:11] {2391} INFO -  at 200.2s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:11] {2218} INFO - iteration 207, current learner xgboost
# [flaml.automl.logger: 12-13 12:20:11] {2391} INFO -  at 201.0s,	estimator xgboost's best error=0.0735,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:11] {2218} INFO - iteration 208, current learner rf
# [flaml.automl.logger: 12-13 12:20:12] {2391} INFO -  at 201.4s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:12] {2218} INFO - iteration 209, current learner rf
# [flaml.automl.logger: 12-13 12:20:12] {2391} INFO -  at 201.6s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:12] {2218} INFO - iteration 210, current learner xgboost
# [flaml.automl.logger: 12-13 12:20:12] {2391} INFO -  at 202.2s,	estimator xgboost's best error=0.0735,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:12] {2218} INFO - iteration 211, current learner rf
# [flaml.automl.logger: 12-13 12:20:13] {2391} INFO -  at 202.4s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:13] {2218} INFO - iteration 212, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:13] {2391} INFO -  at 202.6s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:13] {2218} INFO - iteration 213, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:13] {2391} INFO -  at 202.7s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:13] {2218} INFO - iteration 214, current learner rf
# [flaml.automl.logger: 12-13 12:20:13] {2391} INFO -  at 203.0s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:13] {2218} INFO - iteration 215, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:13] {2391} INFO -  at 203.1s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:13] {2218} INFO - iteration 216, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:15] {2391} INFO -  at 205.1s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:15] {2218} INFO - iteration 217, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:17] {2391} INFO -  at 206.3s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:17] {2218} INFO - iteration 218, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:18] {2391} INFO -  at 207.7s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:18] {2218} INFO - iteration 219, current learner rf
# [flaml.automl.logger: 12-13 12:20:18] {2391} INFO -  at 208.2s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:18] {2218} INFO - iteration 220, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:23] {2391} INFO -  at 213.0s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:23] {2218} INFO - iteration 221, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:23] {2391} INFO -  at 213.2s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:23] {2218} INFO - iteration 222, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:24] {2391} INFO -  at 213.3s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:24] {2218} INFO - iteration 223, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:24] {2391} INFO -  at 214.0s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:24] {2218} INFO - iteration 224, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:29] {2391} INFO -  at 218.3s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:29] {2218} INFO - iteration 225, current learner rf
# [flaml.automl.logger: 12-13 12:20:29] {2391} INFO -  at 218.4s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:29] {2218} INFO - iteration 226, current learner lgbm
# [flaml.automl.logger: 12-13 12:20:30] {2391} INFO -  at 219.3s,	estimator lgbm's best error=0.0639,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:30] {2218} INFO - iteration 227, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:30] {2391} INFO -  at 219.5s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:30] {2218} INFO - iteration 228, current learner rf
# [flaml.automl.logger: 12-13 12:20:30] {2391} INFO -  at 219.7s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:30] {2218} INFO - iteration 229, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:30] {2391} INFO -  at 219.8s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:30] {2218} INFO - iteration 230, current learner xgboost
# [flaml.automl.logger: 12-13 12:20:33] {2391} INFO -  at 222.6s,	estimator xgboost's best error=0.0735,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:33] {2218} INFO - iteration 231, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:33] {2391} INFO -  at 222.9s,	estimator extra_tree's best error=0.1118,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:33] {2218} INFO - iteration 232, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:33] {2391} INFO -  at 223.0s,	estimator extra_tree's best error=0.1086,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:33] {2218} INFO - iteration 233, current learner xgboost
# [flaml.automl.logger: 12-13 12:20:37] {2391} INFO -  at 226.6s,	estimator xgboost's best error=0.0735,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:37] {2218} INFO - iteration 234, current learner rf
# [flaml.automl.logger: 12-13 12:20:37] {2391} INFO -  at 227.0s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:37] {2218} INFO - iteration 235, current learner xgb_limitdepth
# [flaml.automl.logger: 12-13 12:20:41] {2391} INFO -  at 230.6s,	estimator xgb_limitdepth's best error=0.1054,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:41] {2218} INFO - iteration 236, current learner xgb_limitdepth
# [flaml.automl.logger: 12-13 12:20:43] {2391} INFO -  at 233.1s,	estimator xgb_limitdepth's best error=0.1054,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:43] {2218} INFO - iteration 237, current learner xgb_limitdepth
# [flaml.automl.logger: 12-13 12:20:47] {2391} INFO -  at 237.2s,	estimator xgb_limitdepth's best error=0.1054,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:47] {2218} INFO - iteration 238, current learner rf
# [flaml.automl.logger: 12-13 12:20:48] {2391} INFO -  at 237.7s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:48] {2218} INFO - iteration 239, current learner rf
# [flaml.automl.logger: 12-13 12:20:48] {2391} INFO -  at 238.0s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:48] {2218} INFO - iteration 240, current learner rf
# [flaml.automl.logger: 12-13 12:20:49] {2391} INFO -  at 238.3s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:49] {2218} INFO - iteration 241, current learner rf
# [flaml.automl.logger: 12-13 12:20:49] {2391} INFO -  at 238.8s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:49] {2218} INFO - iteration 242, current learner rf
# [flaml.automl.logger: 12-13 12:20:50] {2391} INFO -  at 239.3s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:50] {2218} INFO - iteration 243, current learner rf
# [flaml.automl.logger: 12-13 12:20:50] {2391} INFO -  at 239.6s,	estimator rf's best error=0.1150,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:50] {2218} INFO - iteration 244, current learner extra_tree
# [flaml.automl.logger: 12-13 12:20:50] {2391} INFO -  at 239.8s,	estimator extra_tree's best error=0.1086,	best estimator lgbm's best error=0.0639
# [flaml.automl.logger: 12-13 12:20:50] {2218} INFO - iteration 245, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 12-13 12:20:52] {2391} INFO -  at 242.0s,	estimator lrl1's best error=0.0511,	best estimator lrl1's best error=0.0511
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [flaml.automl.logger: 12-13 12:20:55] {2627} INFO - retrain lrl1 for 3.2s
# [flaml.automl.logger: 12-13 12:20:55] {2630} INFO - retrained model: LogisticRegression(n_jobs=-1, penalty='l1', solver='saga')
# [flaml.automl.logger: 12-13 12:20:56] {1930} INFO - fit succeeded
# [flaml.automl.logger: 12-13 12:20:56] {1931} INFO - Time taken to find the best model: 242.0083611011505
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print(f'Best accuracy on validation data: {(1-automl.best_loss):.3f}')
print(f'Training duration of best run: {(automl.best_config_train_time):.4f} s')
# Out:
# Best ML leaner: lrl1
# Best hyperparmeter config: {'C': 1.0}
# Best accuracy on validation data: 0.949
# Training duration of best run: 3.1666 s

# %%
automl.model.estimator
# Out:
# LogisticRegression(n_jobs=-1, penalty='l1', solver='saga')

# %%
ypred = automl.predict(Xtest)

# %%
(ypred == ytest).mean()
# Out:
# 0.953125
