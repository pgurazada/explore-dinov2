# %% [markdown]
# <a href="https://colab.research.google.com/github/pgurazada/explore-dinov2/blob/main/indian_food_classification_dinov2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this exercise, we train a classification model that uses the feature extraction capabilities of [Dino V2](https://arxiv.org/pdf/2304.07193.pdf).

# %% [markdown]
# # Imports

# %%
# !pip install -q datasets flaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.2 MB/s eta 0:00:00

# %%
import os
import torch
import io

import numpy as np
import torchvision.transforms as T

from PIL import Image
from tqdm import tqdm
from datasets import load_dataset
from flaml import AutoML

# %%
# !pip show torch torchvision
# Out:
# Name: torch
# Version: 2.1.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: fastai, torchaudio, torchdata, torchtext, torchvision
# ---
# Name: torchvision
# Version: 0.16.0+cu118
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, pillow, requests, torch
# Required-by: fastai

# %% [markdown]
# # Data

# %%
indian_foods_ds = load_dataset("bharat-raghunathan/indian-foods-dataset")
# Out:
# Downloading readme:   0%|          | 0.00/2.79k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/281M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/261M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/147M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/3809 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/961 [00:00<?, ? examples/s]

# %%
train_data = list(indian_foods_ds['train'])

# %%
test_data = list(indian_foods_ds['test'])

# %% [markdown]
# # Model for Embeddings

# %%
dinov2_vit14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vitb14")
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vitb14_pretrain.pth
# 100%|██████████| 330M/330M [00:01<00:00, 193MB/s]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
dinov2_vit14.to(device)
# Out:
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
transform_image = T.Compose(
    [
        T.ToTensor(),
        T.Resize(244, antialias=True),
        T.CenterCrop(224),
        T.Normalize([0.5], [0.5])
    ]
)

# %%
def load_image(img: str) -> torch.Tensor:
    """
    Load an image and return a tensor that can be used as an input to DINOv2.
    """

    transformed_img = transform_image(img)[:3].unsqueeze(0)

    return transformed_img

# %%
def compute_embeddings(files: list) -> dict:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    all_embeddings = {}
    bad_image_indices = []

    with torch.no_grad():
      for i, file in enumerate(tqdm(files)):
        try:
            embeddings = dinov2_vit14(load_image(file['image']).to(device))
            all_embeddings[i] = np.array(embeddings[0].cpu().numpy()).reshape(1, -1).tolist()
        except Exception as e:
            bad_image_indices.append(i)
            continue

    return all_embeddings, bad_image_indices

# %%
train_embeddings, bad_train_image_indices = compute_embeddings(train_data)
# Out:
# 100%|██████████| 3809/3809 [01:29<00:00, 42.35it/s]

# %%
len(train_embeddings)
# Out:
# 3774

# %%
test_embeddings, bad_test_image_indices = compute_embeddings(test_data)
# Out:
# 100%|██████████| 961/961 [00:30<00:00, 32.00it/s]

# %%
len(test_embeddings)
# Out:
# 955

# %%
ytrain = np.array([file['label'] for file in train_data])
ytrain_cleaned = np.delete(ytrain, bad_train_image_indices)

train_embedding_list = list(train_embeddings.values())
Xtrain = np.array(train_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

# %%
ytest = np.array([file['label'] for file in test_data])
ytest_cleaned = np.delete(ytest, bad_test_image_indices)

test_embedding_list = list(test_embeddings.values())
Xtest = np.array(test_embedding_list).reshape(-1, dinov2_vit14.embed_dim)

# %% [markdown]
# # Model for Classification

# %%
automl = AutoML()

# %%
automl.fit(
    X_train=Xtrain, y_train=ytrain_cleaned,
    time_budget=240,
    log_file_name='indian-food.log',
    task='classification',
    metric='accuracy',
    split_ratio=.3
)
# Out:
# [flaml.automl.logger: 12-13 14:29:58] {1679} INFO - task = classification
# [flaml.automl.logger: 12-13 14:29:58] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-13 14:29:58] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 12-13 14:29:58] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 12-13 14:29:58] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:03] {2344} INFO - Estimated sufficient time budget=50068s. Estimated necessary time budget=1154s.
# [flaml.automl.logger: 12-13 14:30:03] {2391} INFO -  at 5.3s,	estimator lgbm's best error=0.1400,	best estimator lgbm's best error=0.1400
# [flaml.automl.logger: 12-13 14:30:03] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:05] {2391} INFO -  at 7.2s,	estimator lgbm's best error=0.1400,	best estimator lgbm's best error=0.1400
# [flaml.automl.logger: 12-13 14:30:05] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:06] {2391} INFO -  at 8.1s,	estimator lgbm's best error=0.1260,	best estimator lgbm's best error=0.1260
# [flaml.automl.logger: 12-13 14:30:06] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:15] {2391} INFO -  at 17.1s,	estimator lgbm's best error=0.1059,	best estimator lgbm's best error=0.1059
# [flaml.automl.logger: 12-13 14:30:15] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 12-13 14:30:19] {2391} INFO -  at 20.9s,	estimator xgboost's best error=0.1304,	best estimator lgbm's best error=0.1059
# [flaml.automl.logger: 12-13 14:30:19] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 12-13 14:30:20] {2391} INFO -  at 22.6s,	estimator xgboost's best error=0.1304,	best estimator lgbm's best error=0.1059
# [flaml.automl.logger: 12-13 14:30:20] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:21] {2391} INFO -  at 23.5s,	estimator lgbm's best error=0.1059,	best estimator lgbm's best error=0.1059
# [flaml.automl.logger: 12-13 14:30:21] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:24] {2391} INFO -  at 25.9s,	estimator lgbm's best error=0.1059,	best estimator lgbm's best error=0.1059
# [flaml.automl.logger: 12-13 14:30:24] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:31] {2391} INFO -  at 33.8s,	estimator lgbm's best error=0.0840,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:31] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 12-13 14:30:34] {2391} INFO -  at 35.9s,	estimator xgboost's best error=0.1207,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:34] {2218} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:34] {2391} INFO -  at 36.0s,	estimator extra_tree's best error=0.5582,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:34] {2218} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:34] {2391} INFO -  at 36.1s,	estimator extra_tree's best error=0.4138,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:34] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:34] {2391} INFO -  at 36.1s,	estimator extra_tree's best error=0.4138,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:34] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:34] {2391} INFO -  at 36.2s,	estimator extra_tree's best error=0.4138,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:34] {2218} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:34] {2391} INFO -  at 36.3s,	estimator extra_tree's best error=0.3727,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:34] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 12-13 14:30:36] {2391} INFO -  at 38.3s,	estimator xgboost's best error=0.1207,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:36] {2218} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:36] {2391} INFO -  at 38.4s,	estimator extra_tree's best error=0.3727,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:36] {2218} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 12-13 14:30:38] {2391} INFO -  at 40.5s,	estimator lgbm's best error=0.0840,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:38] {2218} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:38] {2391} INFO -  at 40.6s,	estimator extra_tree's best error=0.3237,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:38] {2218} INFO - iteration 19, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:38] {2391} INFO -  at 40.7s,	estimator extra_tree's best error=0.1907,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:38] {2218} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:38] {2391} INFO -  at 40.8s,	estimator extra_tree's best error=0.1907,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:38] {2218} INFO - iteration 21, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:39] {2391} INFO -  at 40.9s,	estimator extra_tree's best error=0.1907,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:39] {2218} INFO - iteration 22, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:39] {2391} INFO -  at 41.1s,	estimator extra_tree's best error=0.1137,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:39] {2218} INFO - iteration 23, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:39] {2391} INFO -  at 41.2s,	estimator extra_tree's best error=0.1137,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:39] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:39] {2391} INFO -  at 41.5s,	estimator extra_tree's best error=0.1024,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:39] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:39] {2391} INFO -  at 41.6s,	estimator extra_tree's best error=0.1024,	best estimator lgbm's best error=0.0840
# [flaml.automl.logger: 12-13 14:30:39] {2218} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:40] {2391} INFO -  at 42.3s,	estimator extra_tree's best error=0.0779,	best estimator extra_tree's best error=0.0779
# [flaml.automl.logger: 12-13 14:30:40] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:41] {2391} INFO -  at 43.1s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:41] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:41] {2391} INFO -  at 43.7s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:41] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:42] {2391} INFO -  at 44.1s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:42] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 12-13 14:30:46] {2391} INFO -  at 48.2s,	estimator xgboost's best error=0.1207,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:46] {2218} INFO - iteration 31, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:47] {2391} INFO -  at 49.2s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:47] {2218} INFO - iteration 32, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:48] {2391} INFO -  at 49.9s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:48] {2218} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 12-13 14:30:49] {2391} INFO -  at 51.8s,	estimator xgboost's best error=0.1207,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:49] {2218} INFO - iteration 34, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:50] {2391} INFO -  at 52.1s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:50] {2218} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:50] {2391} INFO -  at 52.6s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:50] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:51] {2391} INFO -  at 53.0s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:51] {2218} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:51] {2391} INFO -  at 53.6s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:51] {2218} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:52] {2391} INFO -  at 54.0s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:52] {2218} INFO - iteration 39, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:52] {2391} INFO -  at 54.6s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:52] {2218} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 12-13 14:30:53] {2391} INFO -  at 55.2s,	estimator extra_tree's best error=0.0595,	best estimator extra_tree's best error=0.0595
# [flaml.automl.logger: 12-13 14:30:53] {2218} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 12-13 14:31:10] {2391} INFO -  at 72.0s,	estimator lgbm's best error=0.0490,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:10] {2218} INFO - iteration 42, current learner extra_tree
# [flaml.automl.logger: 12-13 14:31:11] {2391} INFO -  at 72.9s,	estimator extra_tree's best error=0.0595,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:11] {2218} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 12-13 14:31:11] {2391} INFO -  at 73.4s,	estimator extra_tree's best error=0.0569,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:11] {2218} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 12-13 14:31:11] {2391} INFO -  at 73.7s,	estimator rf's best error=0.5372,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:11] {2218} INFO - iteration 45, current learner rf
# [flaml.automl.logger: 12-13 14:31:12] {2391} INFO -  at 73.9s,	estimator rf's best error=0.4051,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:12] {2218} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 12-13 14:31:12] {2391} INFO -  at 74.0s,	estimator rf's best error=0.4051,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:12] {2218} INFO - iteration 47, current learner rf
# [flaml.automl.logger: 12-13 14:31:12] {2391} INFO -  at 74.8s,	estimator rf's best error=0.3298,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:12] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 12-13 14:31:18] {2391} INFO -  at 79.9s,	estimator lgbm's best error=0.0490,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:18] {2218} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 12-13 14:31:18] {2391} INFO -  at 80.6s,	estimator rf's best error=0.3298,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:18] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 12-13 14:31:19] {2391} INFO -  at 81.0s,	estimator extra_tree's best error=0.0534,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:19] {2218} INFO - iteration 51, current learner extra_tree
# [flaml.automl.logger: 12-13 14:31:19] {2391} INFO -  at 81.4s,	estimator extra_tree's best error=0.0534,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:19] {2218} INFO - iteration 52, current learner extra_tree
# [flaml.automl.logger: 12-13 14:31:20] {2391} INFO -  at 82.1s,	estimator extra_tree's best error=0.0534,	best estimator lgbm's best error=0.0490
# [flaml.automl.logger: 12-13 14:31:20] {2218} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 12-13 14:32:29] {2391} INFO -  at 151.5s,	estimator lgbm's best error=0.0376,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:32:29] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 12-13 14:33:15] {2391} INFO -  at 197.8s,	estimator lgbm's best error=0.0376,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:15] {2218} INFO - iteration 55, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:16] {2391} INFO -  at 198.1s,	estimator extra_tree's best error=0.0534,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:16] {2218} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 12-13 14:33:17] {2391} INFO -  at 199.2s,	estimator rf's best error=0.3298,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:17] {2218} INFO - iteration 57, current learner rf
# [flaml.automl.logger: 12-13 14:33:17] {2391} INFO -  at 199.4s,	estimator rf's best error=0.3298,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:17] {2218} INFO - iteration 58, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:17] {2391} INFO -  at 199.8s,	estimator extra_tree's best error=0.0534,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:17] {2218} INFO - iteration 59, current learner rf
# [flaml.automl.logger: 12-13 14:33:18] {2391} INFO -  at 200.5s,	estimator rf's best error=0.2065,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:18] {2218} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 12-13 14:33:19] {2391} INFO -  at 200.9s,	estimator rf's best error=0.2065,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:19] {2218} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 12-13 14:33:19] {2391} INFO -  at 201.5s,	estimator rf's best error=0.2065,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:19] {2218} INFO - iteration 62, current learner rf
# [flaml.automl.logger: 12-13 14:33:21] {2391} INFO -  at 203.3s,	estimator rf's best error=0.0919,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:21] {2218} INFO - iteration 63, current learner rf
# [flaml.automl.logger: 12-13 14:33:21] {2391} INFO -  at 203.9s,	estimator rf's best error=0.0919,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:21] {2218} INFO - iteration 64, current learner rf
# [flaml.automl.logger: 12-13 14:33:28] {2391} INFO -  at 210.6s,	estimator rf's best error=0.0796,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:28] {2218} INFO - iteration 65, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:29] {2391} INFO -  at 211.0s,	estimator extra_tree's best error=0.0490,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:29] {2218} INFO - iteration 66, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:30] {2391} INFO -  at 212.2s,	estimator extra_tree's best error=0.0455,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:30] {2218} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:30] {2391} INFO -  at 212.6s,	estimator extra_tree's best error=0.0455,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:30] {2218} INFO - iteration 68, current learner rf
# [flaml.automl.logger: 12-13 14:33:32] {2391} INFO -  at 214.6s,	estimator rf's best error=0.0796,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:32] {2218} INFO - iteration 69, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:33] {2391} INFO -  at 215.2s,	estimator extra_tree's best error=0.0455,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:33] {2218} INFO - iteration 70, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:35] {2391} INFO -  at 217.3s,	estimator extra_tree's best error=0.0455,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:35] {2218} INFO - iteration 71, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:39] {2391} INFO -  at 221.0s,	estimator extra_tree's best error=0.0402,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:39] {2218} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:41] {2391} INFO -  at 223.0s,	estimator extra_tree's best error=0.0402,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:41] {2218} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:45] {2391} INFO -  at 226.9s,	estimator extra_tree's best error=0.0402,	best estimator lgbm's best error=0.0376
# [flaml.automl.logger: 12-13 14:33:45] {2218} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:48] {2391} INFO -  at 230.1s,	estimator extra_tree's best error=0.0280,	best estimator extra_tree's best error=0.0280
# [flaml.automl.logger: 12-13 14:33:48] {2218} INFO - iteration 75, current learner extra_tree
# [flaml.automl.logger: 12-13 14:33:56] {2391} INFO -  at 238.1s,	estimator extra_tree's best error=0.0280,	best estimator extra_tree's best error=0.0280
# [flaml.automl.logger: 12-13 14:33:56] {2218} INFO - iteration 76, current learner xgb_limitdepth
# [flaml.automl.logger: 12-13 14:33:58] {2391} INFO -  at 240.3s,	estimator xgb_limitdepth's best error=0.1575,	best estimator extra_tree's best error=0.0280
# [flaml.automl.logger: 12-13 14:34:03] {2627} INFO - retrain extra_tree for 4.6s
# [flaml.automl.logger: 12-13 14:34:03] {2630} INFO - retrained model: ExtraTreesClassifier(criterion='entropy', max_features=0.12458198341734236,
#                      max_leaf_nodes=999, n_estimators=124, n_jobs=-1,
#                      random_state=12032022)
# [flaml.automl.logger: 12-13 14:34:03] {1930} INFO - fit succeeded
# [flaml.automl.logger: 12-13 14:34:03] {1931} INFO - Time taken to find the best model: 230.10413646697998

# %%
print('Best ML leaner:', automl.best_estimator)
print('Best hyperparmeter config:', automl.best_config)
print(f'Best accuracy on validation data: {(1-automl.best_loss):.3f}')
print(f'Training duration of best run: {(automl.best_config_train_time):.4f} s')
# Out:
# Best ML leaner: extra_tree
# Best hyperparmeter config: {'n_estimators': 124, 'max_features': 0.12458198341734236, 'max_leaves': 999, 'criterion': 'entropy'}
# Best accuracy on validation data: 0.972
# Training duration of best run: 4.6179 s

# %%
automl.model.estimator
# Out:
# ExtraTreesClassifier(criterion='entropy', max_features=0.12458198341734236,
#                      max_leaf_nodes=999, n_estimators=124, n_jobs=-1,
#                      random_state=12032022)

# %%
ypred = automl.predict(Xtest)

# %%
(ypred == ytest_cleaned).mean()
# Out:
# 0.9727748691099476
